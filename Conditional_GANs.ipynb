# %% [markdown]
# # Implementation of Conditional GANs
# Reference: https://arxiv.org/pdf/1411.1784.pdf

# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import imageio

# %%
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision import transforms
from torchvision.utils import save_image

# %%
import numpy as np
import datetime
import scipy.misc

# %%
MODEL_NAME = 'ConditionalGAN'
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
num_pixels=4096
num_classes=25

# %%
def to_cuda(x):
    return x.to(DEVICE)

# %%
def to_onehot(x, num_classes=25):
    assert isinstance(x, int) or isinstance(x, (torch.LongTensor, torch.cuda.LongTensor))
    if isinstance(x, int):
        c = torch.zeros(1, num_classes).long()
        c[0][x] = 1
    else:
        x = x.cpu()
        c = torch.LongTensor(x.size(0), num_classes)
        c.zero_()
        c.scatter_(1, x, 1) # dim, index, src value
    return c

# %%
def get_sample_image(G, n_noise=100):
    """
        save sample 250 images
    """
    for num in range(25):
        c = to_cuda(to_onehot(num))
        for i in range(10):
            z = to_cuda(torch.randn(1, n_noise))
            y_hat = G(z,c)
            line_img = torch.cat((line_img, y_hat.view(64, 64, 3)), dim=1) if i > 0 else y_hat.view(64, 64, 3)
        all_img = torch.cat((all_img, line_img), dim=0) if num > 0 else line_img
    img = all_img.cpu().data.numpy()
    return img

# %%
class Discriminator(nn.Module):
    """
        Simple Discriminator w/ MLP
    """
    def __init__(self, input_size=12288, label_size=25, num_classes=1):
        super(Discriminator, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Linear(input_size+label_size, 200),
            nn.ReLU(),
            nn.Dropout(),
        )
        self.layer2 = nn.Sequential(
            nn.Linear(200, 200),
            nn.ReLU(),
            nn.Dropout(),
        )
        self.layer3 = nn.Sequential(
            nn.Linear(200, num_classes),
            nn.Sigmoid(),
        )
    
    def forward(self, x, y):        
        x, y = x.view(x.size(0), -1), y.view(y.size(0), -1).float()
        v = torch.cat((x, y), 1) # v: [input, label] concatenated vector
        y_ = self.layer1(v)
        y_ = self.layer2(y_)
        y_ = self.layer3(y_)
        return y_

# %%
class Generator(nn.Module):
    """
        Simple Generator w/ MLP
    """
    def __init__(self, input_size=100, label_size=25, num_classes=12288):
        super(Generator, self).__init__()
        self.layer = nn.Sequential(
            nn.Linear(input_size+label_size, 200),
            nn.LeakyReLU(0.2),
            nn.Linear(200, 200),
            nn.LeakyReLU(0.2),
            nn.Linear(200, num_classes),
            nn.Tanh()
        )
        
    def forward(self, x, y):
        x, y = x.view(x.size(0), -1), y.view(y.size(0), -1).float()
        v = torch.cat((x, y), 1) # v: [input, label] concatenated vector
        y_ = self.layer(v)
        y_ = y_.view(x.size(0), 1, 64, 64,3)
        return y_

# %%
D = to_cuda(Discriminator())
G = to_cuda(Generator())

# %%
transform = transforms.Compose([
    transforms.Resize(64),
    transforms.CenterCrop(64),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5),std=(0.5, 0.5, 0.5))
])

# %%
dataset = datasets.ImageFolder('arcDataset', transform=transform)

# %%
batch_size = 64
condition_size = 25

# %%
data_loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True, drop_last=True)

# %%
criterion = nn.BCELoss()
D_opt = torch.optim.Adam(D.parameters())
G_opt = torch.optim.Adam(G.parameters())

# %%
max_epoch = 100 # need more than 200 epochs for training generator
step = 0
n_critic = 5 # for training more k steps about Discriminator
n_noise = 100

# %%
D_labels = to_cuda(torch.ones(batch_size)) # Discriminator Label to real
D_fakes = to_cuda(torch.zeros(batch_size)) # Discriminator Label to fake

# %%
for epoch in range(max_epoch):
    for idx, (images, labels) in enumerate(data_loader):
        step += 1
        # Training Discriminator
        x = to_cuda(images)
        y = labels.view(batch_size, 1)
        y = to_cuda(to_onehot(y))
        x_outputs = D(x, y)
        D_x_loss = criterion(x_outputs, D_labels)

        z = to_cuda(torch.randn(batch_size, n_noise))
        z_outputs = D(G(z, y), y)
        D_z_loss = criterion(z_outputs, D_fakes)
        D_loss = D_x_loss + D_z_loss
        
        D.zero_grad()
        D_loss.backward()
        D_opt.step()
        
        if step % n_critic == 0:
            # Training Generator
            z = to_cuda(torch.randn(batch_size, n_noise))
            z_outputs = D(G(z, y), y)
            G_loss = criterion(z_outputs, D_labels)

            G.zero_grad()
            G_loss.backward()
            G_opt.step()
        
        if step % 1000 == 0:
            print('Epoch: {}/{}, Step: {}, D Loss: {}, G Loss: {}'.format(epoch, max_epoch, step, D_loss.data[0], G_loss.data[0]))
            
        if epoch % 5 == 0:
            G.eval()
            img = get_sample_image(G)
            imageio.imwrite('sample/{}_epoch_{}_type1.jpg'.format(MODEL_NAME, epoch), img)
            G.train()
# Out:
# C:\Users\Cole\compsci\Anaconda\lib\site-packages\torch\nn\functional.py:1594: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.5128120183944702, 0.4855431318283081]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.4603683352470398, 0.47234848141670227]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.47798851132392883, 0.4821219742298126]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.4835297465324402, 0.5127444267272949]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.4427514374256134, 0.44595009088516235]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.44008877873420715, 0.4670335650444031]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.4415828585624695, 0.45206475257873535]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.46795153617858887, 0.4804162085056305]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.4452357888221741, 0.4272284507751465]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.417366087436676, 0.4199303686618805]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.42064109444618225, 0.40424591302871704]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.4358980357646942, 0.41000044345855713]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.39032506942749023, 0.39009493589401245]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.41756126284599304, 0.42751893401145935]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.39502209424972534, 0.3792699873447418]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.37924841046333313, 0.3566546142101288]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.3636120557785034, 0.41018304228782654]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.3546256124973297, 0.36376363039016724]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.3837818205356598, 0.37133827805519104]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.3820629119873047, 0.3911147117614746]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.339638888835907, 0.3801704943180084]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.35057294368743896, 0.37032634019851685]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.35795271396636963, 0.3661283850669861]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.3576887249946594, 0.38158920407295227]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.4053598940372467, 0.3962118625640869]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.374713659286499, 0.39971861243247986]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.40310823917388916, 0.3917756676673889]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.4297678768634796, 0.4919740855693817]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.3805939257144928, 0.3697959780693054]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.42469000816345215, 0.42000332474708557]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.4486132860183716, 0.4409196972846985]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.43038490414619446, 0.4383007287979126]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.402599036693573, 0.3968210816383362]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.40193235874176025, 0.4166104793548584]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.441592812538147, 0.4387062191963196]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.46492716670036316, 0.45136892795562744]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.4970586895942688, 0.4570702016353607]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.4757280647754669, 0.4350135028362274]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.4461042881011963, 0.44853663444519043]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.514968991279602, 0.5066927075386047]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0
. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.8682081699371338, 0.9093137979507446]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.9138180017471313, 0.8933623433113098]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.9152044653892517, 0.895148754119873]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.9109190106391907, 0.9436900019645691]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.8713335990905762, 0.9237827062606812]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.9035021662712097, 0.9336442947387695]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.8795052766799927, 0.9062677025794983]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-0.9197314977645874, 0.9492006301879883]. Convert image to uint8 prior to saving to suppress this warning.
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-19-173772291077> in <module>()
#      34             G.eval()
#      35             img = get_sample_image(G)
# ---> 36             imageio.imwrite('sample/{}_epoch_{}_type1.jpg'.format(MODEL_NAME, epoch), img)
#      37             G.train()
#
# ~\compsci\Anaconda\lib\site-packages\imageio\core\functions.py in imwrite(uri, im, format, **kwargs)
#     256
#     257     # Get writer and write first
# --> 258     writer = get_writer(uri, format, "i", **kwargs)
#     259     with writer:
#     260         writer.append_data(im)
#
# ~\compsci\Anaconda\lib\site-packages\imageio\core\functions.py in get_writer(uri, format, mode, **kwargs)
#     185
#     186     # Return its writer object
# --> 187     return format.get_writer(request)
#     188
#     189
#
# ~\compsci\Anaconda\lib\site-packages\imageio\core\format.py in get_writer(self, request)
#     186                 "Format %s cannot write in mode %r" % (self.name, select_mode)
#     187             )
# --> 188         return self.Writer(self, request)
#     189
#     190     def can_read(self, request):
#
# ~\compsci\Anaconda\lib\site-packages\imageio\core\format.py in __init__(self, format, request)
#     222             self._request = request
#     223             # Open the reader/writer
# --> 224             self._open(**self.request.kwargs.copy())
#     225
#     226         @property
#
# ~\compsci\Anaconda\lib\site-packages\imageio\plugins\pillow.py in _open(self, quality, progressive, optimize, **kwargs)
#     470             kwargs["optimize"] = bool(progressive)
#     471
# --> 472             PillowFormat.Writer._open(self)
#     473             self._meta.update(kwargs)
#     474
#
# ~\compsci\Anaconda\lib\site-packages\imageio\plugins\pillow.py in _open(self)
#     178             except KeyError:
#     179                 raise RuntimeError("Format %s cannot write images." % self.format.name)
# --> 180             self._fp = self.request.get_file()
#     181             self._meta = {}
#     182             self._written = False
#
# ~\compsci\Anaconda\lib\site-packages\imageio\core\request.py in get_file(self)
#     340         elif self._uri_type == URI_FILENAME:
#     341             if want_to_write:
# --> 342                 self._file = open(self.filename, "wb")
#     343             else:
#     344                 self._file = open(self.filename, "rb")
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\Cole\\compsci\\CS230\\GAN-Tutorial\\Notebooks\\sample\\ConditionalGAN_epoch_45_type1.jpg'

# %% [markdown]
# ## Sample

# %%
# generation to image
G.eval()
scipy.misc.toimage(get_sample_image(G))

# %%
def save_checkpoint(state, file_name='checkpoint.pth.tar'):
    torch.save(state, file_name)

# %%
# Saving params.
# torch.save(D.state_dict(), 'D_c.pkl')
# torch.save(G.state_dict(), 'G_c.pkl')
save_checkpoint({'epoch': epoch + 1, 'state_dict':D.state_dict(), 'optimizer' : D_opt.state_dict()}, 'D_c.pth.tar')
save_checkpoint({'epoch': epoch + 1, 'state_dict':G.state_dict(), 'optimizer' : G_opt.state_dict()}, 'G_c.pth.tar')
